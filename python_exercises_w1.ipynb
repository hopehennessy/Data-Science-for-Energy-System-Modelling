# %% [markdown]
# # Workshop 1: Python

# %% [markdown]
# Task 1: What is 5 to the power of 5 minus 5?

# %%
5**5 - 5
# Out:
# 3120

# %% [markdown]
# Task 2: Create variables for the efficiency of 45% and the input_energy of 1000 MWh. Compute and print the output_energy using these variables.

# %%
efficiency = 0.45
input_energy = 1000
output_energy = input_energy * efficiency
output_energy
# Out:
# 450.0

# %% [markdown]
# Task 4: Create a list with the names of every planet in the solar system (in order).
#
# Have Python tell you the name of the third planet.
# Have Python tell you the total number of planets.
# Have Python tell you whether “Pluto” is in the list of planets.
# Iterate through your planets and print the planet name only if it has an “s” at the end.

# %%
planets = ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"]

planets[2]
len(planets)
"Pluto" in planets

for planet in planets:
    if planet.endswith("s"):
        print(planet)
# Out:
# False

# %% [markdown]
# Task 5: Create a dictionary that contains the main facts about the Reuter West power plant.
#
# Have Python tell you the main fuel type used in the power plant.
# Add the power plant’s approximate latitude and longitude to the dictionary.

# %%
reuter_west = {
    "name": "Reuter West Power Plant",
    "location": "Berlin, Germany",
    "type": "Combined Heat and Power (CHP)",
    "main_fuel": "Hard coal",
    "capacity_MW": 560
}

print("Main fuel type:", reuter_west["main_fuel"])

reuter_west["latitude"] = 52.536
reuter_west["longitude"] = 13.229

print(reuter_west)
# Out:
# Main fuel type: Hard coal
# {'name': 'Reuter West Power Plant', 'location': 'Berlin, Germany', 'type': 'Combined Heat and Power (CHP)', 'main_fuel': 'Hard coal', 'capacity_MW': 560, 'latitude': 52.536, 'longitude': 13.229}

# %% [markdown]
# Task 6: Write a function that converts units of energy from ‘ktoe’ to ‘GWh’

# %%
def ktoe_to_gwh(ktoe):
    return ktoe * 11.63

ktoe_to_gwh(100)
# Out:
# 1163.0

# %% [markdown]
# Task 7: Write a more general unit conversion function that converts between all units of energy listed under the link below. The function should take arguments: for the original value, the original unit and the target unit. Implement the function in a way that the default target unit is “Wh”. Verify that function by converting 200 ‘toe’ to ‘Wh’.

# %%
def convert_energy(value, from_unit, to_unit="Wh"):
    # Conversion factors TO joules (J)
    to_joules = {
        "J": 1,
        "Wh": 3600,
        "kWh": 3.6e6,
        "MWh": 3.6e9,
        "GWh": 3.6e12,
        "TWh": 3.6e15,
        "EJ": 1e18,
        "toe": 41.868e9,
        "Mtoe": 41.868e15,
        "tce": 29.3076e9,
        "Mtce": 29.3076e15,
        "Btu": 1055.06,
        "TBtu": 1.05506e15,
        "cal": 4.184,
        "Pcal": 4.184e15
    }

    # Convert input value to joules
    value_in_joules = value * to_joules[from_unit]

    # Convert joules to target unit
    converted_value = value_in_joules / to_joules[to_unit]

    return converted_value

convert_energy(200, "toe")
# Out:
# 2326000000.0
